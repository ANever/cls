# %%
function_list = ['s', 'i', 'r', 'ps', 'pi', 'pr']
variable_list = ['t','x']

from clspde.solution import lp as l

def lp(line, function_list=function_list, variable_list = variable_list):
    res = l(line, function_list, variable_list)
    return lambda u_loc, u_bas, x, x_loc: eval(res)
    
#simple direct problem solving 

import matplotlib.pyplot as plt

from clspde.solution import Solution
from clspde.basis import Basis
import itertools
import numpy as np

a = 1
b = 1

eps = 0.05

beta = 1
gamma = 0.15

power = 4
params = {
    'n_dims': 2,
    'dim_sizes': np.array([3, 3]),
    'area_lims': np.array([[0,0.1], [0,1]]),
    'power': power,
    'basis': Basis(power),
    'n_funcs': 6,
}
sol = Solution(**params)

w = 1
k1 = 10
k2 = 0.5
border_weight = 100
no_need_weight = 0


def f_collocation_points(N):
    points = np.zeros(N+1)
    h = 2/(N+1)
    points[0] = -1 + h/2
    for i in range(1, N+1):
        points[i] = points[i-1] + h
    return np.array(points).reshape(N+1,1)

c_p_1d = f_collocation_points(power).reshape(power+1)

colloc_points = np.array(list(itertools.product(c_p_1d, c_p_1d)))


connect_points = np.array([[-1, 0.5], [1, 0.5],
                            [0.5, -1], [0.5, 1],
                            [-1, -0.5], [1, -0.5],
                            [-0.5, -1], [-0.5, 1],])
                            
border_points = connect_points

colloc_left_operators = [
    #KFP s
    lp('(d/dt) s - eps * (d/dx)^2 s + beta * ( s * &i + &s * i ) -' +
    '( (d/dx) s * (d/dx) &ps + (d/dx) &s * (d/dx) ps +' +
    ' s * (d/dx)^2 &ps + &s * (d/dx)^2 ps )'),
    #KFP i
    lp('(d/dt) i - eps * (d/dx)^2 i - beta * ( s * &i + &s * i ) +' +
    'gamma * i -' +
    '( (d/dx) i * (d/dx) &pi + (d/dx) &i * (d/dx) pi +' +
    ' i * (d/dx)^2 &pi + &i * (d/dx)^2 pi )'),
    #KFP r
    lp('(d/dt) r - eps * (d/dx)^2 r - gamma * i -' +
    '( (d/dx) r * (d/dx) &pr + (d/dx) &r * (d/dx) pr +' +
    ' r * (d/dx)^2 &pr + &r * (d/dx)^2 pr )'),
    #HJB ps
    lp('- (d/dt) ps - eps * (d/dx)^2 ps +' +
    'beta*( i * ( &ps - &pi ) + &i * ( ps - pi ))+' +
    '( (d/dx) ps * (d/dx) &ps )'),
    #HJB pi
    lp('- (d/dt) pi - eps * (d/dx)^2 pi -' +
    'beta*( s * ( &ps - &pi ) + &s * ( ps - pi ))+' +
    'gamma * ( pi - pr ) + ' + 
    '( (d/dx) pi * (d/dx) &pi )'),
    #HJB pr
    lp('- (d/dt) pr - eps * (d/dx)^2 pr +' +
    '( (d/dx) pr * (d/dx) &pr )'),
    ]

colloc_right_operators = [
    lp('- (d/dx) &s * (d/dx) &ps - &s * (d/dx)^2 &ps + beta * &s * &i'),
    lp('- (d/dx) &i * (d/dx) &pi - &i * (d/dx)^2 &pi - beta * &s * &i'),
    lp('- (d/dx) &r * (d/dx) &pr - &r * (d/dx)^2 &pr'),
    lp('beta * &i * ( &ps - &pi ) + ( (d/dx) &ps )**2/2'),
    lp('-beta * &s * ( &ps - &pi ) + ( (d/dx) &pi )**2/2'),
    lp('( (d/dx) &pr )**2/2'),
    ]


def initial_state(x):
    t, x = x
    sm_x = 3*x-1
    if (x<2/3 and x>1/3):
        return np.array([0.97, 0.02, 0.01]) * 3 * 12 * (sm_x**2) *(1-sm_x)
    else:
        return np.array([0,0,0])

def terminal_state(x):
    sm_x = 3*x-1
    if (x<2/3 and x>1/3):
        return np.array([0, 0., 0.])* 12*sm_x*(1-sm_x)**2 *3
    else:
        return [0,0,0]

def Bx(x):
    #border condition for x
    return int((x[1]==sol.area_lims[1,0]) or (x[1]==sol.area_lims[1,1]))

def BtI(x):
    #border condition Initial for t
    return int(x[0]==sol.area_lims[0,0])

def BtT(x):
    #border condtition Terminal for t
    return int(x[0]==sol.area_lims[0,1])

border_left_operators = [
    lp('Bx(x) * s'),
    lp('Bx(x) * i'),
    lp('Bx(x) * r'),
    lp('Bx(x) * ps'),
    lp('Bx(x) * pi'),
    lp('Bx(x) * pr'),

    lp('BtI(x) * s'),
    lp('BtI(x) * i'),
    lp('BtI(x) * r'),
    lp('BtT(x) * ps'),
    lp('BtT(x) * ( pi - i )'),
    lp('BtT(x) * pr'),
    ]

border_right_operators = [
    lp('Bx(x) * initial_state(x)[0]'),
    lp('Bx(x) * initial_state(x)[1]'),
    lp('Bx(x) * initial_state(x)[2]'),
    lp('Bx(x) * 0'),
    lp('Bx(x) * 0'),
    lp('Bx(x) * 0'),

    lp('BtI(x) * initial_state(x)[0]'),
    lp('BtI(x) * initial_state(x)[1]'),
    lp('BtI(x) * initial_state(x)[2]'),
    lp('BtT(x) * (-terminal_state(x[1])[0])'),
    lp('BtT(x) * (-terminal_state(x[1])[1])'),
    lp('BtT(x) * (-terminal_state(x[1])[2])'),
    ]

def f_collocation_points(N):
    points = np.zeros(N+1)
    h = 2/(N+1)
    points[0] = -1 + h/2
    for i in range(1, N+1):
        points[i] = points[i-1] + h
    return np.array(points).reshape(N+1,1)

c_p_1d = f_collocation_points(power).reshape(power+1)

colloc_points = np.array(list(itertools.product(c_p_1d, c_p_1d)))
connect_points = np.array([
                            [-1, 0.5], [1, 0.5],
                            [0.5, -1], [0.5, 1],
                            [-1, -0.5], [1, -0.5],
                            [-0.5, -1], [-0.5, 1],
                            [-1, 0], [1, 0],
                            [0, -1], [0, 1],
                            ])
border_points = connect_points
points=[colloc_points, connect_points ,border_points]

connect_left_operators = []
connect_right_operators = []

def dir(point: np.array) -> np.array:
    direction = (np.abs(point) == 1) * (np.sign(point))
    return np.array(direction, dtype=int)
for func_num in range(sol.n_funcs):
    # connect_left_operators += [lambda _, u_bas, x, x_loc, func_num=func_num: u_bas(0*dir(x_loc),func_num) + np.sum(dir(x_loc))*int(abs(x_loc[1])==1)*u_bas([0,1],func_num)]
    # connect_right_operators += [lambda _, u_bas, x, x_loc, func_num=func_num: u_bas(0*dir(x_loc),func_num) -  np.sum(dir(x_loc))*int(abs(x_loc[1])==1)*u_bas([0,1],func_num)]
    connect_left_operators += [lambda _, u_bas, x, x_loc, func_num=func_num: k1*u_bas(0*dir(x_loc),func_num) + k2*np.sum(dir(x_loc))*u_bas([0,1],func_num) * np.prod(dir(np.array([0.5,1]))==[0,1])]
    connect_right_operators += [lambda _, u_bas, x, x_loc, func_num=func_num: k1*u_bas(0*dir(x_loc),func_num) -  k2*np.sum(dir(x_loc))*u_bas([0,1],func_num) * np.prod(dir(np.array([0.5,-1]))==[0,-1])]

colloc_ops = [colloc_left_operators, colloc_right_operators]
border_ops = [border_left_operators, border_right_operators]
connect_ops = [connect_left_operators, connect_right_operators]

iteration_dict = {'points':points,
        'colloc_ops':colloc_ops,
        'border_ops':border_ops,
       'connect_ops':connect_ops
}

sol.cells_coefs *= 0.0

# %% [markdown]
# Переформулировать условие на S компоненту, чтобы она отображала экономическую составляющую модели.

# %%
sol.cell_division(1)

# %%
import copy
k=200
n=20
small = 10**(-5)
ts = np.linspace(params['area_lims'][0,0],params['area_lims'][0,1] - small, n)
xs = np.linspace(params['area_lims'][1,0],params['area_lims'][1,1] - small, n)

def ev(sol, ts=ts, xs=xs):
    res_array = np.zeros((len(ts), len(xs)))
    for i in range(len(ts)):
        t = ts[i]
        for j in range(len(xs)):
            x = xs[j]
            res_array[i,j] = sol.eval(np.array([t,x]), [0,0])
    return res_array

new_eval=ev(sol)
division_counter = 0
for j in range(k):
    prev_eval = new_eval
    prev_coefs = copy.deepcopy(sol.cells_coefs)
    A, b = sol.global_solve(solver='np', return_system=True, **iteration_dict)
    new_eval = ev(sol)
    change = np.max(np.abs(prev_eval - new_eval))
    print(j,' | ', np.max(np.abs(prev_coefs - sol.cells_coefs)),' | ', change)
    if change < 1e-4:
        sol.plot2d()
        division_counter +=1
        sol.cell_division(1)#(division_counter % 2)
# Out:
# 0  |  4.114408633617102  |  4.675210743447217
# 1  |  0.8855752568703732  |  0.5800745956156153
# 2  |  0.43941348292569815  |  0.5225829705805183
# 3  |  0.22634465290848294  |  0.2740783597041112
# 4  |  0.1595421191713804  |  0.18308832235151762
# 5  |  0.15602877633651868  |  0.18223902276254478
# 6  |  0.1532644254705624  |  0.17704135520733777
# 7  |  0.151670386598866  |  0.17452652221302278
# 8  |  0.14941325320617027  |  0.17219846286459228
# 9  |  0.1474184287234337  |  0.16960915845891744
# 10  |  0.14562015424965846  |  0.16770609390369628
# 11  |  0.14393627754632332  |  0.16559811010134862
# 12  |  0.14251001240873862  |  0.16407221877455314
# 13  |  0.1411665374036586  |  0.16241201715146225
# 14  |  0.14003841517987858  |  0.16119944303014444
# 15  |  0.13896932651513172  |  0.159886200052755
# 16  |  0.1380723424952528  |  0.15891960409114692
# 17  |  0.13721819245458677  |  0.1578736926606501
# 18  |  0.13650029963675925  |  0.15709881268488868
# 19  |  0.13581433341109994  |  0.15626039490032717
# 20  |  0.13523627915678782  |  0.15563573054838686
# 21  |  0.13468256567249304  |  0.15495976184291793
# 22  |  0.13421468451446872  |  0.15445371958076315
# 23  |  0.13376567976445308  |  0.15390603057071983
# 24  |  0.13338532860200614  |  0.15349438633640933
# 25  |  0.13301980540474068  |  0.15304879737806232
# 26  |  0.13270950305482732  |  0.1527127915716604
# 27  |  0.13241096459307355  |  0.1523490290859444
# 28  |  0.1321570672471668  |  0.1520739872541852
# 29  |  0.13191257680194113  |  0.15177618992180175
# 30  |  0.13170433202054754  |  0.1515505277186402
# 31  |  0.13150365724127822  |  0.15130617073522545
# 32  |  0.13133251970814985  |  0.15112066945133407
# 33  |  0.13116750574324998  |  0.15091978328545164
# 34  |  0.13102663578263707  |  0.15076705641205645
# 35  |  0.1308907406893436  |  0.15060165106997658
# 36  |  0.1307746311421063  |  0.15047574602764513
# 37  |  0.1306625774228829  |  0.1503393807983575
# 38  |  0.1305667715080312  |  0.15023547694624417
# 39  |  0.13047428201252353  |  0.1501229351938007
# 40  |  0.13039515809163404  |  0.15003711294383226
# 41  |  0.13031875251200375  |  0.149944152074311
# 42  |  0.13025335737881916  |  0.14987321373689078
# 43  |  0.13019019481907312  |  0.1497963720726183
# 44  |  0.13013611320915386  |  0.14973770140170162
# 45  |  0.1300838683852592  |  0.149674146515411
# 46  |  0.13003912036617127  |  0.14962559812138787
# 47  |  0.1299958854901062  |  0.14957300682185082
# 48  |  0.12995884471265962  |  0.14953281796638507
# 49  |  0.12992305200623822  |  0.1494892815336386
# 50  |  0.1298923804057135  |  0.14945600161498485
# 51  |  0.12986273916814728  |  0.14941994898859967
# 52  |  0.12983733427553057  |  0.14939238259937637
# 53  |  0.12981278069593527  |  0.14936251909986886
# 54  |  0.12979173314975556  |  0.1493396800569502
# 55  |  0.12977138946392053  |  0.1493149375673708
# 56  |  0.12975394850568245  |  0.14929601159422745
# 57  |  0.1297370898026471  |  0.149275508099882
# 58  |  0.12972263505816928  |  0.1492598222589896
# 59  |  0.1297086621587984  |  0.14924282879736994
# 60  |  0.12969668071732698  |  0.14922982667382723
# 61  |  0.12968509821519714  |  0.14921574057082188
# 62  |  0.12967516575374693  |  0.14920496180966802
# 63  |  0.12966556371031102  |  0.14919328440368762
# 64  |  0.12965732908860428  |  0.14918434804158043
# 65  |  0.129649368184781  |  0.14917466658865797
# 66  |  0.12964254062896563  |  0.14916725712211854
# 67  |  0.12963593987517896  |  0.14915922985687669
# 68  |  0.12963027864605792  |  0.14915308607111966
# 69  |  0.1296248053072402  |  0.14914642992115912
# 70  |  0.1296201108122612  |  0.1491413352323976
# 71  |  0.12961557209377927  |  0.14913581571310752
# 72  |  0.1296116791836277  |  0.1491315909209554
# 73  |  0.12960791540593064  |  0.14912701382434834
# 74  |  0.12960468704193184  |  0.14912351021632286
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 22
#      20 prev_eval = new_eval
#      21 prev_coefs = copy.deepcopy(sol.cells_coefs)
# ---> 22 A, b = sol.global_solve(solver='np', return_system=True, **iteration_dict)
#      23 new_eval = ev(sol)
#      24 change = np.max(np.abs(prev_eval - new_eval))
#
# File ~/miniconda3/envs/knk/lib/python3.9/site-packages/clspde-0.0.1-py3.9.egg/clspde/solution.py:633, in Solution.global_solve(self, solver, return_system, calculate, svd_threshold, verbose, alpha, **kwargs)
#     632 def global_solve(self, solver = 'np',return_system = False, calculate = True, svd_threshold = 1e-4, verbose = False, alpha=0,  **kwargs):
# --> 633     A, b = self.generate_global_system(**kwargs)
#     635     if alpha > 0:
#     636         A = concat(A, np.eye(A.shape[1])*alpha)
#
# File ~/miniconda3/envs/knk/lib/python3.9/site-packages/clspde-0.0.1-py3.9.egg/clspde/solution.py:588, in Solution.generate_global_system(self, points, colloc_ops, border_ops, connect_ops, connect_weight, function_list, variable_list)
#     585 right_border_for_use = np.array([np.logical_and(point == 1, right_borders).any() for point in border_points])
#     586 border_points_for_use = border_points[np.logical_or(left_border_for_use, right_border_for_use)]
# --> 588 colloc_mat, colloc_r = self.generate_subsystem(colloc_left_operators, colloc_right_operators, cell_num, colloc_points)
#     589 border_mat, border_r = self.generate_subsystem(border_left_operators, border_right_operators, cell_num, border_points_for_use)
#     591 #for 2d only!
#     592 # cell_ind = cell_num[0] + cell_num[1] * self.dim_sizes[0] # + cell_num[2] * prod(self.dim_sizes[:2]...
#
# File ~/miniconda3/envs/knk/lib/python3.9/site-packages/clspde-0.0.1-py3.9.egg/clspde/solution.py:442, in Solution.generate_subsystem(self, left_ops, right_ops, cell_num, points)
#     440 mat, r = self.generate_eq(cell_num, left_ops[0], right_ops[0], points)
#     441 for i in range(1,len(left_ops)):
# --> 442     mat_small, r_small = self.generate_eq(cell_num, left_ops[i], right_ops[i], points)
#     443     mat = concat(mat, mat_small)
#     444     r = concat(r, r_small)
#
# File ~/miniconda3/envs/knk/lib/python3.9/site-packages/clspde-0.0.1-py3.9.egg/clspde/solution.py:436, in Solution.generate_eq(self, cell_num, left_side_operator, right_side_operator, points)
#     434 for i in range(len(points)):
#     435     mat[i] = left_side(left_side_operator, cell_num,  points[i])
# --> 436     r_side[i] = right_side(right_side_operator, cell_num, points[i])
#     437 return mat, r_side
#
# File ~/miniconda3/envs/knk/lib/python3.9/site-packages/clspde-0.0.1-py3.9.egg/clspde/solution.py:430, in Solution.generate_eq.<locals>.right_side(operator, cell_num, point)
#     427 neigh_point = loc_point-2*dir(loc_point)
#     429 u_nei = lambda der, func_num=0: self.eval(neigh_point, der, local = True, cell_num = cell_num + dir(loc_point), func=func_num)
# --> 430 return operator(u_loc, u_nei, global_point, loc_point)
#
# Cell In[41], line 8, in lp.<locals>.<lambda>(u_loc, u_bas, x, x_loc)
#       6 def lp(line, function_list=function_list, variable_list = variable_list):
#       7     res = l(line, function_list, variable_list)
# ----> 8     return lambda u_loc, u_bas, x, x_loc: eval(res)
#
# File <string>:1
#
# File ~/miniconda3/envs/knk/lib/python3.9/site-packages/clspde-0.0.1-py3.9.egg/clspde/solution.py:425, in Solution.generate_eq.<locals>.right_side.<locals>.<lambda>(der, func_num)
#     423 # x = global_point
#     424 loc_point = copy.deepcopy(point)
# --> 425 u_loc = lambda der, func_num=0: self.eval(loc_point, der, local = True, cell_num = cell_num, func=func_num)   # for linearization purpses
#     427 neigh_point = loc_point-2*dir(loc_point)
#     429 u_nei = lambda der, func_num=0: self.eval(neigh_point, der, local = True, cell_num = cell_num + dir(loc_point), func=func_num)
#
# File ~/miniconda3/envs/knk/lib/python3.9/site-packages/clspde-0.0.1-py3.9.egg/clspde/solution.py:232, in Solution.eval(self, point, derivatives, func, cell_num, local, cells_closed_right)
#     230 else:
#     231     cell_num, local_point = self.localize(point, cells_closed_right)
# --> 232 coefs = self.cells_coefs[tuple(np.insert(np.array(cell_num, dtype=int), 0, func))]
#     233 result = copy.deepcopy(coefs)
#     234 #applying coefs tensor to evaled basis in point
#
# File <__array_function__ internals>:200, in insert(*args, **kwargs)
#
# File ~/miniconda3/envs/knk/lib/python3.9/site-packages/numpy/lib/function_base.py:5399, in insert(arr, obj, values, axis)
#    5394 values = array(values, copy=False, ndmin=arr.ndim, dtype=arr.dtype)
#    5395 if indices.ndim == 0:
#    5396     # broadcasting is very different here, since a[:,0,:] = ... behaves
#    5397     # very different from a[:,[0],:] = ...! This changes values so that
#    5398     # it works likes the second case. (here a[:,0:1,:])
# -> 5399     values = np.moveaxis(values, 0, axis)
#    5400 numnew = values.shape[axis]
#    5401 newshape[axis] += numnew
#
# File <__array_function__ internals>:200, in moveaxis(*args, **kwargs)
#
# File ~/miniconda3/envs/knk/lib/python3.9/site-packages/numpy/core/numeric.py:1468, in moveaxis(a, source, destination)
#    1465     transpose = a.transpose
#    1467 source = normalize_axis_tuple(source, a.ndim, 'source')
# -> 1468 destination = normalize_axis_tuple(destination, a.ndim, 'destination')
#    1469 if len(source) != len(destination):
#    1470     raise ValueError('`source` and `destination` arguments must have '
#    1471                      'the same number of elements')
#
# File ~/miniconda3/envs/knk/lib/python3.9/site-packages/numpy/core/numeric.py:1398, in normalize_axis_tuple(axis, ndim, argname, allow_duplicate)
#    1396         pass
#    1397 # Going via an iterator directly is slower than via list comprehension.
# -> 1398 axis = tuple([normalize_axis_index(ax, ndim, argname) for ax in axis])
#    1399 if not allow_duplicate and len(set(axis)) != len(axis):
#    1400     if argname:
#
# File ~/miniconda3/envs/knk/lib/python3.9/site-packages/numpy/core/numeric.py:1398, in <listcomp>(.0)
#    1396         pass
#    1397 # Going via an iterator directly is slower than via list comprehension.
# -> 1398 axis = tuple([normalize_axis_index(ax, ndim, argname) for ax in axis])
#    1399 if not allow_duplicate and len(set(axis)) != len(axis):
#    1400     if argname:
#
# KeyboardInterrupt:

# %%
for i in range(6):
    sol.plot2d(func_num=i)

# %%
sol.cell_division(1)
